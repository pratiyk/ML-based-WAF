# %% [markdown]
# ### Analysis of Parsed NGINX Access Logs

# %%
import numpy as np

# %%
import pandas as pd

# %%
access_logs=pd.read_csv('access_logs.csv')

# %%
access_logs.head()
# Out:
#     IP Address                  Timestamp HTTP Method  \
# 0  172.18.28.9  2024-09-11T00:00:40+05:30         GET
# 1  172.18.28.9  2024-09-11T00:00:40+05:30        POST
# 2  172.18.28.9  2024-09-11T00:01:05+05:30         GET
# 3  172.18.28.9  2024-09-11T00:01:06+05:30        POST
# 4  172.18.28.9  2024-09-11T00:01:31+05:30         GET
#
#                                         Request Path  Status Code  \
# 0  /socket.io/?EIO=4&transport=polling&t=P7TDBHF&...          200
# 1  /socket.io/?EIO=4&transport=polling&t=P7TDHOY&...          200
# 2  /socket.io/?EIO=4&transport=polling&t=P7TDHOY....          200
# 3  /socket.io/?EIO=4&transport=polling&t=P7TDNWZ&...          200
# 4  /socket.io/?EIO=4&transport=polling&t=P7TDNWa&...          200
#
#    Response Size              Referrer  \
# 0              1  https://ss.dmrc.org/
# 1              2  https://ss.dmrc.org/
# 2              1  https://ss.dmrc.org/
# 3              2  https://ss.dmrc.org/
# 4              1  https://ss.dmrc.org/
#
#                                           User Agent  Request Length  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             274
# 1  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             275
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             276
# 3  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             275
# 4  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             274
#
#    Query Parameters Count  ... Request Size Distribution User-Agent Diversity  \
# 0                       4  ...                  1.000000                    1
# 1                       4  ...                  1.500000                    1
# 2                       4  ...                  1.333333                    1
# 3                       4  ...                  1.500000                    1
# 4                       4  ...                  1.400000                    1
#
#   Time Interval Between Requests  Path Frequency  Suspicious Patterns  \
# 0                        0:00:00               1                   No
# 1                        0:00:00               1                   No
# 2                 0:00:12.500000               1                   No
# 3                 0:00:08.666667               1                   No
# 4                 0:00:12.750000               1                   No
#
#   SQL Injection Detected  XSS Detected Command Injection Detected  \
# 0                     No            No                         No
# 1                     No            No                         No
# 2                     No            No                         No
# 3                     No            No                         No
# 4                     No            No                         No
#
#    Insecure Deserialization Detected  File Inclusion Detected
# 0                                 No                       No
# 1                                 No                       No
# 2                                 No                       No
# 3                                 No                       No
# 4                                 No                       No
#
# [5 rows x 28 columns]

# %%
n_features=access_logs.shape[1]
n_samples =access_logs.shape[0]

# %%
print(f'number of features: {n_features}')
missing_values_count = access_logs.isnull().sum()
missing_values_count[0:n_features]
# Out:
# number of features: 28
# IP Address                           0
# Timestamp                            0
# HTTP Method                          0
# Request Path                         0
# Status Code                          0
# Response Size                        0
# Referrer                             0
# User Agent                           0
# Request Length                       0
# Query Parameters Count               0
# Is Secure                            0
# Time of Day                          0
# Day of Week                          0
# User-Agent Length                    0
# Referrer Length                      0
# Status Code Category                 0
# Request Frequency                    0
# Status Code Distribution             0
# Request Size Distribution            0
# User-Agent Diversity                 0
# Time Interval Between Requests       0
# Path Frequency                       0
# Suspicious Patterns                  0
# SQL Injection Detected               0
# XSS Detected                         0
# Command Injection Detected           0
# Insecure Deserialization Detected    0
# File Inclusion Detected              0
# dtype: int64

# %%
total_cells = np.prod(access_logs.shape)
total_missing = missing_values_count.sum()
percent_missing = (total_missing/total_cells) * 100
print('percentage missing:',(f'{percent_missing:.2f}') ,'%')
# Out:
# percentage missing: 0.00 %

# %%
for feature in access_logs.columns:
    if feature in access_logs.columns:
        unique_count = access_logs[feature].nunique()
        print(f"Number of unique values for {feature}: {unique_count}")
    else:
        print(f"Column '{feature}' does not exist in the DataFrame.")
# Out:
# Number of unique values for IP Address: 3
# Number of unique values for Timestamp: 10151
# Number of unique values for HTTP Method: 3
# Number of unique values for Request Path: 33216
# Number of unique values for Status Code: 6
# Number of unique values for Response Size: 1238
# Number of unique values for Referrer: 26
# Number of unique values for User Agent: 270
# Number of unique values for Request Length: 285
# Number of unique values for Query Parameters Count: 6
# Number of unique values for Is Secure: 1
# Number of unique values for Time of Day: 10151
# Number of unique values for Day of Week: 1
# Number of unique values for User-Agent Length: 39
# Number of unique values for Referrer Length: 19
# Number of unique values for Status Code Category: 4
# Number of unique values for Request Frequency: 37163
# Number of unique values for Status Code Distribution: 37220
# Number of unique values for Request Size Distribution: 37210
# Number of unique values for User-Agent Diversity: 268
# Number of unique values for Time Interval Between Requests: 36224
# Number of unique values for Path Frequency: 627
# Number of unique values for Suspicious Patterns: 1
# Number of unique values for SQL Injection Detected: 2
# Number of unique values for XSS Detected: 1
# Number of unique values for Command Injection Detected: 2
# Number of unique values for Insecure Deserialization Detected: 1
# Number of unique values for File Inclusion Detected: 1

# %%
command_injection = access_logs[access_logs['Command Injection Detected'] == 'Yes']
print(command_injection)
# Out:
#         IP Address                  Timestamp HTTP Method  \
# 65     172.18.28.9  2024-09-11T00:07:04+05:30        POST
# 66     172.18.28.9  2024-09-11T00:07:04+05:30         GET
# 70     172.18.28.9  2024-09-11T00:07:04+05:30         GET
# 72     172.18.28.9  2024-09-11T00:07:05+05:30         GET
# 77     172.18.28.9  2024-09-11T00:07:28+05:30         GET
# ...            ...                        ...         ...
# 37123  172.18.28.9  2024-09-11T15:37:07+05:30         GET
# 37124  172.18.28.9  2024-09-11T15:37:07+05:30         GET
# 37138  172.18.28.9  2024-09-11T15:37:11+05:30         GET
# 37150  172.18.28.9  2024-09-11T15:37:25+05:30         GET
# 37209  172.18.28.9  2024-09-11T15:42:49+05:30         GET
#
#                                             Request Path  Status Code  \
# 65     /socket.io/?EIO=4&transport=polling&t=P7TElBO&...          200
# 66     /socket.io/?EIO=4&transport=polling&t=P7TElBV&...          200
# 70     /socket.io/?EIO=4&transport=websocket&sid=bi19...          400
# 72     /DB/MapDashboard/viewAssetEqptData/?filter=((l...          200
# 77     /socket.io/?EIO=4&transport=polling&t=P7TElEP&...          200
# ...                                                  ...          ...
# 37123  /DB/ADR/v1/ViewAdrmEmployeeDutyDataFull/?filte...          304
# 37124  /DB/ADR/v1/ViewAdrmEmployeeDutyDataFull/?filte...          304
# 37138  /DB/ADR/v1/ViewAdrmEmployeeDutyDataFull/?filte...          304
# 37150  /DB/ADR/v1/ViewAdrmEmployeeDutyDataFull/?filte...          200
# 37209  /DB/MapDashboard/viewAssetEqptData/?filter=((l...          200
#
#        Response Size                                           Referrer  \
# 65                 2                                  http://localhost/
# 66                32                                  http://localhost/
# 70                45                                                  -
# 72              6998                                                  -
# 77                 1                                  http://localhost/
# ...              ...                                                ...
# 37123              0  https://ss.dmrc.org/duty_roster/edit_chart/CHA...
# 37124              0  https://ss.dmrc.org/duty_roster/edit_chart/CHA...
# 37138              0  https://ss.dmrc.org/duty_roster/edit_chart/CHA...
# 37150           3289  https://ss.dmrc.org/duty_roster/edit_chart/CHA...
# 37209           6604                                                  -
#
#                                               User Agent  Request Length  \
# 65     Mozilla/5.0 (Linux; Android 13; 220333QBI Buil...             323
# 66     Mozilla/5.0 (Linux; Android 13; 220333QBI Buil...             323
# 70     Mozilla/5.0 (Linux; Android 13; 220333QBI Buil...             299
# 72     Dalvik/2.1.0 (Linux; U; Android 13; 220333QBI ...             336
# 77     Mozilla/5.0 (Linux; Android 13; 220333QBI Buil...             322
# ...                                                  ...             ...
# 37123  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             591
# 37124  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             591
# 37138  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             591
# 37150  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             594
# 37209  Dalvik/2.1.0 (Linux; U; Android 11; CPH1937 Bu...             334
#
#        Query Parameters Count  ... Request Size Distribution  \
# 65                          4  ...                 24.272727
# 66                          4  ...                 24.388060
# 70                          3  ...                 24.760563
# 72                          2  ...                120.561644
# 77                          4  ...                224.025641
# ...                       ...  ...                       ...
# 37123                       1  ...               4829.077917
# 37124                       1  ...               4828.947634
# 37138                       1  ...               4831.516262
# 37150                       1  ...               4830.063976
# 37209                       2  ...               4836.512395
#
#       User-Agent Diversity Time Interval Between Requests  Path Frequency  \
# 65                       4                 0:00:05.907692               1
# 66                       4                 0:00:05.818182               1
# 70                       4                 0:00:05.485714               1
# 72                       5                 0:00:05.347222               1
# 77                       5                 0:00:05.298701               1
# ...                    ...                            ...             ...
# 37123                  268                 0:00:01.515945              25
# 37124                  268                 0:00:01.515904              26
# 37138                  268                 0:00:01.515440               9
# 37150                  268                 0:00:01.515327               9
# 37209                  268                 0:00:01.521642               2
#
#        Suspicious Patterns SQL Injection Detected  XSS Detected  \
# 65                      No                     No            No
# 66                      No                     No            No
# 70                      No                     No            No
# 72                      No                     No            No
# 77                      No                     No            No
# ...                    ...                    ...           ...
# 37123                   No                     No            No
# 37124                   No                     No            No
# 37138                   No                     No            No
# 37150                   No                     No            No
# 37209                   No                     No            No
#
#       Command Injection Detected  Insecure Deserialization Detected  \
# 65                           Yes                                 No
# 66                           Yes                                 No
# 70                           Yes                                 No
# 72                           Yes                                 No
# 77                           Yes                                 No
# ...                          ...                                ...
# 37123                        Yes                                 No
# 37124                        Yes                                 No
# 37138                        Yes                                 No
# 37150                        Yes                                 No
# 37209                        Yes                                 No
#
#        File Inclusion Detected
# 65                          No
# 66                          No
# 70                          No
# 72                          No
# 77                          No
# ...                        ...
# 37123                       No
# 37124                       No
# 37138                       No
# 37150                       No
# 37209                       No
#
# [1257 rows x 28 columns]

# %%
suspicious_patterns = access_logs[access_logs['Suspicious Patterns'] == 'Yes']
print(suspicious_patterns)
# Out:
# Empty DataFrame
# Columns: [IP Address, Timestamp, HTTP Method, Request Path, Status Code, Response Size, Referrer, User Agent, Request Length, Query Parameters Count, Is Secure, Time of Day, Day of Week, User-Agent Length, Referrer Length, Status Code Category, Request Frequency, Status Code Distribution, Request Size Distribution, User-Agent Diversity, Time Interval Between Requests, Path Frequency, Suspicious Patterns, SQL Injection Detected, XSS Detected, Command Injection Detected, Insecure Deserialization Detected, File Inclusion Detected]
# Index: []
#
# [0 rows x 28 columns]

# %%
sql_injection = access_logs[access_logs['SQL Injection Detected'] == 'Yes']
print(sql_injection)
# Out:
#         IP Address                  Timestamp HTTP Method  \
# 1710   172.18.28.9  2024-09-11T03:21:58+05:30        POST
# 1711   172.18.28.9  2024-09-11T03:22:23+05:30         GET
# 3504   172.18.28.9  2024-09-11T06:05:23+05:30         GET
# 3953   172.18.28.9  2024-09-11T06:14:51+05:30         GET
# 3987   172.18.28.9  2024-09-11T06:15:24+05:30         GET
# ...            ...                        ...         ...
# 36103  172.18.28.9  2024-09-11T15:21:46+05:30         GET
# 36179  172.18.28.9  2024-09-11T15:23:06+05:30         GET
# 36180  172.18.28.9  2024-09-11T15:23:06+05:30         GET
# 37107  172.18.28.9  2024-09-11T15:37:04+05:30         GET
# 37108  172.18.28.9  2024-09-11T15:37:04+05:30         GET
#
#                                             Request Path  Status Code  \
# 1710   /socket.io/?EIO=4&transport=polling&t=P7TxL--&...          200
# 1711   /socket.io/?EIO=4&transport=polling&t=P7TxL--....          200
# 3504   /socket.io/?EIO=4&transport=polling&t=P7UWf--&...          200
# 3953   /DB/v1/ViewTechnicianPendingJobCardData/?filte...          200
# 3987   /DB/v1/ViewTechnicianPendingJobCardData/?filte...          200
# ...                                                  ...          ...
# 36103  /DB/v1/ViewTechnicianPendingJobCardData/?filte...          200
# 36179  /DB/ADR/v1/GetAdrmDutyRoasterChartWithApprover...          304
# 36180  /DB/ADR/v1/GetAdrmDutyRoasterChartWithApprover...          304
# 37107  /DB/ADR/v1/GetAdrmDutyRoasterChartWithApprover...          304
# 37108  /DB/ADR/v1/GetAdrmDutyRoasterChartWithApprover...          304
#
#        Response Size                                        Referrer  \
# 1710               2                            https://ss.dmrc.org/
# 1711               1                            https://ss.dmrc.org/
# 3504               1                               http://localhost/
# 3953            3526                                               -
# 3987            3526                                               -
# ...              ...                                             ...
# 36103           1190                                               -
# 36179              0  https://ss.dmrc.org/duty_roster/chart_approval
# 36180              0  https://ss.dmrc.org/duty_roster/chart_approval
# 37107              0  https://ss.dmrc.org/duty_roster/chart_approval
# 37108              0  https://ss.dmrc.org/duty_roster/chart_approval
#
#                                               User Agent  Request Length  \
# 1710   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             275
# 1711   Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             276
# 3504   Mozilla/5.0 (Linux; Android 9; SM-M307F Build/...             320
# 3953   Dalvik/2.1.0 (Linux; U; Android 14; CPH2381 Bu...             334
# 3987   Dalvik/2.1.0 (Linux; U; Android 14; CPH2381 Bu...             334
# ...                                                  ...             ...
# 36103  Dalvik/2.1.0 (Linux; U; Android 12; CPH2381 Bu...             334
# 36179  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             499
# 36180  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             499
# 37107  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             499
# 37108  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             499
#
#        Query Parameters Count  ... Request Size Distribution  \
# 1710                        4  ...                684.338983
# 1711                        4  ...                683.939836
# 3504                        4  ...                615.051355
# 3953                        2  ...                786.002276
# 3987                        2  ...                781.207874
# ...                       ...  ...                       ...
# 36103                       2  ...               4545.631849
# 36179                       5  ...               4636.710722
# 36180                       5  ...               4636.582360
# 37107                       5  ...               4831.000378
# 37108                       5  ...               4830.869987
#
#       User-Agent Diversity Time Interval Between Requests  Path Frequency  \
# 1710                    15                 0:00:07.063158               1
# 1711                    15                 0:00:07.073641               1
# 3504                    21                 0:00:06.245148               1
# 3953                    27                 0:00:05.679484               1
# 3987                    27                 0:00:05.639328               2
# ...                    ...                            ...             ...
# 36103                  268                 0:00:01.533293               2
# 36179                  268                 0:00:01.532281               3
# 36180                  268                 0:00:01.532239               4
# 37107                  268                 0:00:01.516519               5
# 37108                  268                 0:00:01.516478               6
#
#        Suspicious Patterns SQL Injection Detected  XSS Detected  \
# 1710                    No                    Yes            No
# 1711                    No                    Yes            No
# 3504                    No                    Yes            No
# 3953                    No                    Yes            No
# 3987                    No                    Yes            No
# ...                    ...                    ...           ...
# 36103                   No                    Yes            No
# 36179                   No                    Yes            No
# 36180                   No                    Yes            No
# 37107                   No                    Yes            No
# 37108                   No                    Yes            No
#
#       Command Injection Detected  Insecure Deserialization Detected  \
# 1710                          No                                 No
# 1711                          No                                 No
# 3504                          No                                 No
# 3953                          No                                 No
# 3987                          No                                 No
# ...                          ...                                ...
# 36103                         No                                 No
# 36179                        Yes                                 No
# 36180                        Yes                                 No
# 37107                        Yes                                 No
# 37108                        Yes                                 No
#
#        File Inclusion Detected
# 1710                        No
# 1711                        No
# 3504                        No
# 3953                        No
# 3987                        No
# ...                        ...
# 36103                       No
# 36179                       No
# 36180                       No
# 37107                       No
# 37108                       No
#
# [225 rows x 28 columns]
